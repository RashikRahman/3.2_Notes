# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>

# %% [markdown]
# # Video Link : https://photos.app.goo.gl/ZLR3LPCmM7bXomVK6

# %% [markdown]
# { There's nothing to understand from this lecture, just basic stuff so i just copied pages from pdf and pasted here. Just added some side notes in some figures. }

# %% [markdown]
# ![image.png](figures/fig161.PNG)
#
# ![image.png](figures/fig162.PNG)
#
# **The arduino doesn't require a separate part of hardware to run basic programs. Basic programs can be handled by its own micro processor but in case you need to extend digital pin or you need more memory to run a certain program then separate hardware components will be needed.**
#
# ![image.png](figures/fig163.PNG)
#
# **Arduino is very helpful in project prototyping and in many more sectors. And it's open source.**
#
# ![image.png](figures/fig164.PNG)
#
# ![image.png](figures/fig165.PNG)
#
# **Digital pin are very important.**
#
# ![image.png](figures/fig166.PNG)
#
# ![image.png](figures/fig167.PNG)
#
# ![image.png](figures/fig168.PNG)
#
# There are total 14 digital I/O pins. These pin's input/output can be only represented by 0/1. There are 6 analog pins to read fractional data.
#
# ![image.png](figures/fig169.PNG)
#
# ![image.png](figures/fig1610.PNG)
#
# ![image.png](figures/fig1611.PNG)
#
# ![image.png](figures/fig1612.PNG)
#
# ![image.png](figures/fig1613.PNG)
#
# ![image.png](figures/fig1614.PNG)
#
# ![image.png](figures/fig1615.PNG)
#
# ![image.png](figures/fig1616.PNG)
#
# ![image.png](figures/fig1617.PNG)
#
# ![image.png](figures/fig1618.PNG)
#
# ![image.png](figures/fig1619.PNG)
#
# ![image.png](figures/fig1620.PNG)

# %% [markdown]
# ![image.png](figures/fig1621.PNG)
#
# ![image.png](figures/fig1622.PNG)
#
# ![image.png](figures/fig1623.PNG)
#
# ![image.png](figures/fig1624.PNG)
#
# ![image.png](figures/fig1625.PNG)
#
# ![image.png](figures/fig1626.PNG)
#
# ![image.png](figures/fig1627.PNG)
#
# ![image.png](figures/fig1628.PNG)
#
# ![image.png](figures/fig1629.PNG)
#
# **ProtoShield helps to add more pins to the board. It acts like a pin hub. So it increases the number of pins.** Like you have 14 digital I/O pins in UNO but you need 20pins for your project then you can use this to extend the number of pins.
#
# ![image.png](figures/fig1630.PNG)
#
# ![image.png](figures/fig1631.PNG)
#
# ![image.png](figures/fig1632.PNG)
#
# **Using touchpad shield you can implement more security settings. Like setting up a password that will be entered by user via this touchpad interface.** Numeric touchpad only has 0-9 and alpha numeric has a-z,0-9.
#
# ![image.png](figures/fig1633.PNG)
#
# ![image.png](figures/fig1634.PNG)
#
# ![image.png](figures/fig1635.PNG)
#
# ![image.png](figures/fig1636.PNG)
#
# ![image.png](figures/fig1637.PNG)
#
# ![image.png](figures/fig1638.PNG)

# %% [markdown]
# # That's all for todays lecture!
