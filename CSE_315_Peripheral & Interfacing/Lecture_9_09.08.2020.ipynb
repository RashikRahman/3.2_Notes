# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>
#
# # [Click here to see class lecture](https://photos.app.goo.gl/YgzhTN5uJ91kKe7W7)

# %% [markdown]
# ### Today's topic is Input Device : Scanner (2D)
#
# Scanner is mainly an input device that converts a image into digital form ( basically 0 & 1 ).
#
# ![image.png](figures/fig41.PNG)
#
# Classification of Scanner :
#
# ![image.png](figures/fig42.PNG)
#
# In flatbed scanner document is stationary. This means that the document won't move it will be fixed in it's place. The head will move and scan the document.
#
# ![image.png](figures/fig43.PNG)
#
# In sheet fed head is stationary it will be in a fixed position and the document will move for scanning.
#
# ![image.png](figures/fig44.PNG)
#
# ![image.png](figures/fig45.PNG)
#
# ![image.png](figures/fig46.PNG)

# %% [markdown]
# **Important for exam. (Anatomy of flatbed scanner)**
#
# ![image.png](figures/fig47.PNG)
#
# ![image.png](figures/fig48.PNG)
#
# ![image.png](figures/fig49.PNG)
#
# ![image.png](figures/fig50.PNG)
#
# ![image.png](figures/fig51.PNG)
#
# ![image.png](figures/fig52.PNG)

# %% [markdown]
# # Thats all for this lecture!
