% %% [markdown]
% ![image.png](figures/fig8.PNG)

% %% [markdown]
% ## Task 1

% %%
x = [-3.5,-5,6.2,11,0,8.1,-9,0,3,-1,3,2.5];
p=[];
n=[];
cntp=1;
cntn=1;
for i = 1:rows(x)
  for j = 1:columns(x)
      if (x(i,j)<0)
          n(cntn,:) = x(i,j);
          cntn = cntn+1;
      else
          p(cntp,:) = x(i,j);
          cntp = cntp+1;
      endif
    
  endfor
endfor

p = p(p!=0)
n
% Out:
% p =
%
%     6.2000
%    11.0000
%     8.1000
%     3.0000
%     3.0000
%     2.5000
%
% n =
%
%   -3.5000
%   -5.0000
%   -9.0000
%   -1.0000

% %% [markdown]
% ## Task 2

% %%
allMarks=[ 24   44   36   36
       52   57   68   76
       66   53   69   73
       85   40   86   72
       15   47   25   28
       79   72   82   91];

% %%
scale_marks = allMarks*0.2 #scale down to 20%
% Out:
% scale_marks =
%
%     4.8000    8.8000    7.2000    7.2000
%    10.4000   11.4000   13.6000   15.2000
%    13.2000   10.6000   13.8000   14.6000
%    17.0000    8.0000   17.2000   14.4000
%     3.0000    9.4000    5.0000    5.6000
%    15.8000   14.4000   16.4000   18.2000

% %%
depak = allMarks(4,:)
depak_total_marks = sum(depak)
% Out:
% depak =
%
%    85   40   86   72
%
% depak_total_marks =  283

% %%
programing = allMarks(:,2)
% Out:
% programing =
%
%    44
%    57
%    53
%    40
%    47
%    72

% %%
mechanics = allMarks(:,4)
% Out:
% mechanics =
%
%    36
%    76
%    73
%    72
%    28
%    91

% %%
average_of_programming = mean(programing)
% Out:
% average_of_programming =  52.167

% %%
average_of_mechanics = mean(mechanics)
% Out:
% average_of_mechanics =  62.667
