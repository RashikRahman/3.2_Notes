# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>

# %% [markdown]
# # Video Link : https://photos.app.goo.gl/ck2QmtBc6GJrshxV9

# %% [markdown]
# # Terminologies<br>
# End device : Desktop, Mobile, Laptop, Server etc<br>
# Network Device : Switch, Router etc<br>
# TCP/IP Layer : <ul>
#                <li>Application layer</li>
#               <li>Transport Layer</li>
#                <li>Internet Layer</li>
#               <li>Network Access Layer</li>
#               <li>Physical Layer</li>
#             </ul>

# %% [markdown]
# ![image.png](figures/fig1.PNG)<br>
#
# There are two types of connection wire used **cross over** and **straight**. **Cross over is used to connect same devices and straight wire is used to connect different type of devices.**
# We established a physical connection with wires but to communicate we need to setup a logical connection using IP address.

# %% [markdown]
# # IP Address
# We use IPV4 like 192.168.0.1<br> here the pattern is like A.A.A.A where each A is of 8 bit so total size of IPV4 is 32 bit.<br>IP address = Network address(N) + Host address(H).The combination can be like <ol><li>N.N.N.H</li><li>N.N.H.H</li><li>N.H.H.H</li></ol>Now in the 8 bit of each address what's the **min & max value** min is 0 and max is 255. so it's like 0 ~ 255.0 ~ 255.0 ~ 255.0 ~ 255. But in the host address part we need to reserve two addresses one reserved for network and another one reserved for broadcast. So in 1st combination we can connect 256-2=254 devices. and the range of address should be 1 ~ 254.<br> **Ex** : 192.168.0.0 -- Network address reserved<br>192.168.0.255 -- Broadcast address reserved<br>  In the 2nd combination there are total 2 host address so total connection will be 2^16(as each is 8bit) - 2 = 65534. And in the 3rd combination we can connect 2^24 - 2 = 16million devices.

# %% [markdown]
# The are types of IP address called class. <ol><li>Class C (H <= 254)</li><li>Class B (H <= 65534)</li><li>Class A (H <= 16millions)</li></ol>These classes are based on host connection requirements. **Now how to understand which IP belongs to which class?**<br> To answer thi we need to look at the fisrt octect of the IP that is the first A from A.A.A.A .<br>
# <ul><li>1 ~ 127 = Class A</li><li>128 ~ 191 = Class B</li><li>192 ~ 223 = Class C</li></ul>As an example 192.168.0.1 here the first octect is 192 so it belongs to class C.<br>

# %% [markdown]
# # Let's see IP setup in Cisco Packet Tracer
# ![image.png](figures/fig2.PNG)![image.png](figures/fig3.PNG)

# %% [markdown]
# # Let's ping and check ping status.
# Ping is just to check if you have established connection logically.
# ![image.png](figures/fig5.PNG)
# ![image.png](figures/fig4.PNG)<br> Here we are using pc3 to ping which has ip 192.168.0.1 and we are pinging pc4 which has ip 192.168.0.2 . So in the command prompt of pc3 we write **ping 192.168.0.2**. And we can see that it sent 4 packets to pc4 and pc4 replied with acknowledgement. If we pinged another address that is not in network then it would return time out as it can't find that host.

# %% [markdown]
# # Connection using Switch
# To connect multiple devices together we use switch. As switch and end devices are different type of devices so we use straight connection to connect them and then do ip address setup.<br>![image.png](figures/fig6.PNG)<br>

# %% [markdown]
# <br>![image.png](figures/fig7.PNG)<br>Up untill now we saw just realtime now let's see simulation. Click simulation->Edit filter->ICMP(as we will just send packets). Now we again ping from laptop1 to laptop4 just for example and see the simulation![image.png](figures/fig8.jpg)<br> This is the cycle of the 1st packet it will repeat 4 times like this

# %% [markdown]
# ## Client & Server Network
# Up untill now we only just connected computers with each other but there is no service to this setup. So to make a client server arrangement we will have to setup a server which will serve the connected clients. In this setup the client will sent a request like http repuest and server will serve the request so that client can access the web.
# ![image.jpg](figures/fig9.jpg)<br>
# First we setup the server by giving it it's ip address then goto services turn http and dns on and in dns set name and address(same as server address). Then click on laptop and goto ip config then there in dns give the server dns address that is same as server ip address. Then from browser give the name of site that you entered in dns and it will appear.

# %% [markdown]
# # This was all for this lecture.
