# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>
#
# # [Click here to see class lecture](https://photos.app.goo.gl/51rcLBWYqSZxZjcs9)

# %% [markdown]
# ### Today's agenda is to design a system like this.
#
# We'll use VLSM and RIP version 2(CLI config) etc
#
# ![image.png](figures/fig83.PNG)
#
# ![image.png](figures/fig84.PNG)

# %% [markdown]
# ![image.png](figures/fig85.PNG)
#
# If router base network is given in the question then we start router calculation from the base network otherwise we continue with the already VLSM calculation just like last lab. In this lab we'll use 10.10.10.0/30
#
# ![image.png](figures/fig86.PNG)
#
# <p>&nbsp;network administrator assumes the base network is 172.54.0.0/16</p>
# <p><br /><br /></p>
# <table width="696">
# <tbody>
# <tr>
# <td>
# <p>Name</p>
# </td>
# <td>
# <p>Host requirements</p>
# </td>
# <td>
# <p>Network Address</p>
# </td>
# <td>
# <p>Subnet mask</p>
# </td>
# <td>
# <p>First Host</p>
# </td>
# <td>
# <p>Last Host</p>
# </td>
# <td>
# <p>Broadcast Address</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>UAP</p>
# </td>
# <td>
# <p>8000</p>
# </td>
# <td>
# <p>172.54.0.0/19</p>
# </td>
# <td>
# <p>255.255.224.0</p>
# </td>
# <td>
# <p>172.54.0.1</p>
# </td>
# <td>
# <p>172.54.31.254</p>
# </td>
# <td>
# <p>172.54.31.255</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>NSU</p>
# </td>
# <td>
# <p>5000</p>
# </td>
# <td>
# <p>172.54.32.0/19</p>
# </td>
# <td>
# <p>255.255.224.0</p>
# </td>
# <td>
# <p>172.54.32.1</p>
# </td>
# <td>
# <p>172.54.63.254</p>
# </td>
# <td>
# <p>172.54.63.255</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>DU</p>
# </td>
# <td>
# <p>3000</p>
# </td>
# <td>
# <p>172.54.64.0/20</p>
# </td>
# <td>
# <p>255.255.240.0</p>
# </td>
# <td>
# <p>172.54.64.1</p>
# </td>
# <td>
# <p>172.54.79.254</p>
# </td>
# <td>
# <p>172.54.79.255</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>JU</p>
# </td>
# <td>
# <p>1000</p>
# </td>
# <td>
# <p>172.54.80.0/22</p>
# </td>
# <td>
# <p>255.255.252.0</p>
# </td>
# <td>
# <p>172.54.80.1</p>
# </td>
# <td>
# <p>172.54.83.254</p>
# </td>
# <td>
# <p>172.54.83.255</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>Internet</p>
# </td>
# <td>
# <p>12</p>
# </td>
# <td>
# <p>172.54.84.0/28</p>
# </td>
# <td>
# <p>255.255.255.240</p>
# </td>
# <td>
# <p>172.54.84.1</p>
# </td>
# <td>
# <p>172.54.84.14</p>
# </td>
# <td>
# <p>172.54.84.15</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>DNS</p>
# </td>
# <td>
# <p>4</p>
# </td>
# <td>
# <p>172.54.84.16/29</p>
# </td>
# <td>
# <p>255.255.255.248</p>
# </td>
# <td>
# <p>172.54.84.17</p>
# </td>
# <td>
# <p>172.54.84.22</p>
# </td>
# <td>
# <p>172.54.84.23</p>
# </td>
# </tr>
# <tr>
# </tr>
# <tr>
# </tr>
# <tr>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# Let's configure hosts.
#
# ![image.png](figures/fig87.PNG)
#
# ![image.png](figures/fig88.PNG)
#
# ![image.png](figures/fig89.PNG)
#
# ![image.png](figures/fig90.PNG)
#
# ![image.png](figures/fig91.PNG)
#
# ![image.png](figures/fig92.PNG)
#
# ![image.png](figures/fig93.PNG)
#
# ![image.png](figures/fig94.PNG)
#
# ![image.png](figures/fig95.PNG)
#
# ![image.png](figures/fig96.PNG)
#
# ![image.png](figures/fig97.PNG)
#
# ![image.png](figures/fig98.PNG)
#
# For all server goto services->http and edit index.html
#
# ![image.png](figures/fig99.PNG)
#
# ![image.png](figures/fig100.PNG)
#
# ![image.png](figures/fig101.PNG)
#
# ![image.png](figures/fig102.PNG)

# %% [markdown]
# ## Routing Config
#
# ![image.png](figures/fig103.PNG)
#
#
# **Router base address 10.10.10.0/30**
#
# <table width="696">
# <tbody>
# <tr>
# <td>
# <p>Name</p>
# </td>
# <td>
# <p>Host requirements</p>
# </td>
# <td>
# <p>Network Address</p>
# </td>
# <td>
# <p>Subnet mask</p>
# </td>
# <td>
# <p>First Host</p>
# </td>
# <td>
# <p>Last Host</p>
# </td>
# <td>
# <p>Broadcast Address</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>R6 - R1</p>
# </td>
# <td>
# <p>2</p>
# </td>
# <td>
# <p>10.10.10.0/30</p>
# </td>
# <td>
# <p>255.255.255.252</p>
# </td>
# <td>
# <p>10.10.10.1</p>
# </td>
# <td>
# <p>10.10.10.2</p>
# </td>
# <td>
# <p>10.10.10.3</p>
# </td>
# </tr>
# <tr>
# <td>R1-R2</td>
# <td>
# <p>2</p>
# </td>
# <td>
# <p>10.10.10.4</p>
# </td>
# <td>
# <p>255.255.255.252</p>
# </td>
# <td>
# <p>10.10.10.5</p>
# </td>
# <td>
# <p>10.10.10.6</p>
# </td>
# <td>
# <p>10.10.10.7</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>R1-R3</p>
# </td>
# <td>
# <p>2</p>
# </td>
# <td>
# <p>10.10.10.8</p>
# </td>
# <td>
# <p>255.255.255.252</p>
# </td>
# <td>
# <p>10.10.10.9</p>
# </td>
# <td>
# <p>10.10.10.10</p>
# </td>
# <td>
# <p>10.10.10.11</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>R3-R4</p>
# </td>
# <td>
# <p>2</p>
# </td>
# <td>
# <p>10.10.10.12</p>
# </td>
# <td>
# <p>255.255.255.252</p>
# </td>
# <td>
# <p>10.10.10.13</p>
# </td>
# <td>
# <p>10.10.10.14</p>
# </td>
# <td>
# <p>10.10.10.15</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>R4-R2</p>
# </td>
# <td>
# <p>2</p>
# </td>
# <td>
# <p>10.10.10.16</p>
# </td>
# <td>
# <p>255.255.255.252</p>
# </td>
# <td>
# <p>10.10.10.17</p>
# </td>
# <td>
# <p>10.10.10.18</p>
# </td>
# <td>
# <p>10.10.10.19</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>R4-R5</p>
# </td>
# <td>
# <p>2</p>
# </td>
# <td>10.10.10.20</td>
# <td>
# <p>255.255.255.252</p>
# </td>
# <td>
# <p>10.10.10.21</p>
# </td>
# <td>
# <p>10.10.10.22</p>
# </td>
# <td>
# <p>10.10.10.23</p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## R6-R1
#
# ![image.png](figures/fig104.PNG)
#
# ![image.png](figures/fig105.PNG)
#
# ## R1-R2
#
# ![image.png](figures/fig106.PNG)
#
# ![image.png](figures/fig107.PNG)
#
# ## R1-R3
#
# ![image.png](figures/fig108.PNG)
#
# ![image.png](figures/fig109.PNG)
#
# ## R3-R4
#
# ![image.png](figures/fig110.PNG)
#
# ![image.png](figures/fig111.PNG)
#
# ## R4-R2
#
# ![image.png](figures/fig112.PNG)
#
# ![image.png](figures/fig113.PNG)
#
# ## R4-R5
#
# ![image.png](figures/fig114.PNG)
#
# ![image.png](figures/fig115.PNG)

# %% [markdown]
# ## Routing Config (CLI + RIP V2)
#
# config steps:
# 0. command : ena
# 1. We need to find the connected network addresses (show ip route), command : show ip route
# 2. configure in terminal, command : configure terminal
# 3. router rip, command : router rip
# 4. version 2, command : version 2
# 5. no auto-summary, command : no auto-summary
# 6. we will add all connected networks in the RIP, command : network n.n.n.n( here it is the ip address that we can see in show ip route and has a 'c' written before it.)
#
#
# ![image.png](figures/fig116.PNG)
#
# ![image.png](figures/fig117.PNG)
#
# ![image.png](figures/fig118.PNG)
#
# ![image.png](figures/fig119.PNG)
#
# ![image.png](figures/fig120.PNG)
#
# ![image.png](figures/fig121.PNG)

# %% [markdown]
# **RESULT**
#
# So the network works.
#
# ![image.png](figures/fig122.PNG)

# %% [markdown]
# # That's all for this lab!
