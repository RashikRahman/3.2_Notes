# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>
#
# # [Click here to see class lecture](https://photos.app.goo.gl/6x3eMgBcRqJFbthW7)

# %% [markdown]
# ## This is a review class
#
# **Learn to convert bin -> hex -> bin.**
#
# ![image.png](figures/fig69.PNG)
#
# ![image.png](figures/fig70.PNG)
#
# ![image.png](figures/fig71.PNG)
#
# ![image.png](figures/fig72.PNG)
#
# ![image.png](figures/fig73.PNG)

# %% [markdown]
# # That's all for this lecture!
