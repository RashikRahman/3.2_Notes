# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>
#
# # [Click here to see class lecture](https://drive.google.com/file/d/1VCB-Ckk2TW8jv71CnjN3X2HTWqY6IKGz/view)

# %% [markdown]
# We'll follow same procedures as lab 2. Verify this code then copy the hex path to the program file in proteus software then simulate it. Then we'll see a fading effect.
#
# ![image.png](figures/fig30.PNG)
#
# ![image.png](figures/fig29.PNG)

# %% [markdown]
# Now let's print something using serial port.
#
# ![image.png](figures/fig31.PNG)

# %% [markdown]
# Goto proteus select arduino uno like you did in previous lab. Then to select virtual terminal, click 1, then click 2 and drop it to they layout. connect arduino pin 1(TXD) to virtual terminal's RXD and arduino pin 0(RXD) to virtual terminal's TXD. Then simulate it like you have done in previous lab. Thus you'll get the output. Don't forget to provide the hex file path to the program file in proteus software.
#
# ![image.png](figures/fig32.PNG)
#
# **OUTPUT**
#
# ![image.png](figures/fig33.PNG)

# %% [markdown]
# # That's all for this lab!
