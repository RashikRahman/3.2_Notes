# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>
#
# # [Click here to see class lecture](https://drive.google.com/file/d/1x7nRf2yxZFqpYTSXr8MZvFQ6OOZ09ywY/view)

# %% [markdown]
# ## Task 1 :
#
# **Take input from one pin and output it to another.**
#
# ![image.png](figures/fig34.PNG)
#
# ![image.png](figures/fig35.PNG)
#
# ![image.png](figures/fig36.PNG)
#
# ![image.png](figures/fig37.PNG)
#
# paste the hex path and run it.
#
# ![image.png](figures/fig38.PNG)

# %% [markdown]
# ## Task 2 :
#
# **Do transfer, not operation**
#
# `Description :` Write a function that will do the following task. If a switch is high then it will do transfer operation other wise it will do not operation depending on the input pin.
#
# ![image.png](figures/fig39.PNG)
#
# paste the hex file path and run to see results.
#
# ![image.png](figures/fig40.gif)

# %% [markdown]
# ## Task 3 :
#
# **Add two more operations to task 2**
#
# `Description :` add another switch, if high then AND operation will happen otherwise OR operation will happen. You are to take two separate input for this. The output will be showed via different pin.
#
#
#
#
# paste the hex file path and run to see results.
#
# ![image.png](figures/fig42.PNG)
#
# ![image.png](figures/fig43.PNG)
#
# ![image.png](figures/fig41.gif)

# %% [markdown]
# # That's all for this lab!
