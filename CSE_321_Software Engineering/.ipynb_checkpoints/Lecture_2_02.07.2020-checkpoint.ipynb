# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>

# %% [markdown]
# # Video Link : https://photos.app.goo.gl/EXHqaPPZmP4b1mVb8

# %% [markdown]
# ![image.png](figures/fig7.PNG)<br>
# **System software :** is a type of computer program that is designed to run a computer's hardware and application programs. If we think of the computer system as a layered model, the system software is the interface between the hardware and user applications.<br>
# **Application software :** is specific to the task it is designed for and can be as simple as a calculator application or as complex as a word processing application. For example, office software suites might include word processing, spreadsheet, database, presentation, and email applications.<br>
# **Scientific and engineering software :** satisfies the needs of a scientific or engineering user to perform enterprise specific tasks. Such software is written for specific applications using principles, techniques and formulae specific to that field. Examples are software like MATLAB, AUTOCAD, PSPICE, ORCAD, etc.<br>
# **Embedded software :** is computer software, written to control machines or devices that are not typically thought of as computers, commonly known as embedded systems. It is typically specialized for the particular hardware that it runs on and has time and memory constraints.<br>
# **WebApps :** Web based application like facebook, daraz, amazon etc.<br>
# **Mobile Apps :** Messenger, Whatsapp etc.<br>
# **AI Software :** Software that is capable of intelligent behavior. This involves simulating a number of capabilities, including reasoning, learning, problem solving, perception, knowledge representation.

# %% [markdown]
# ![image.png](figures/fig8.PNG)<br>
# ![image.png](figures/fig9.PNG)<br>
# ![image.png](figures/fig10.PNG)<br>

# %% [markdown]
# ![image.png](figures/fig11.PNG)<br>
# ![image.png](figures/fig12.PNG)<br>
#
# # There's nothing much to note about in this lecture read slide or watch the video though it won't be much help.
