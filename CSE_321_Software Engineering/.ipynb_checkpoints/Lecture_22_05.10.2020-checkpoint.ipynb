# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>
#
# # [Click here to see class lecture](https://drive.google.com/file/d/1RFa9U_QJsWdwJ1JwqVS8gohCQAPIrH0s/view)

# %% [markdown]
# ![image.png](figures/fig405.PNG)
#
# ![image.png](figures/fig406.PNG)
#
# Some parts of software attributes.
#
# ![image.png](figures/fig407.PNG)
#
# ![image.png](figures/fig408.PNG)
#
# A product's good will is dependent on software quality control. Like samsung's good will was damaged cause their software QC department didn't checked it well.
#
# ![image.png](figures/fig409.PNG)
#
# QA team ensures that they built a solid product and QC team checks that if the product is solid or not. QA are developers and QC are testers. QA is verification QC in validation.
#
# ![image.png](figures/fig410.PNG)
#
# ![image.png](figures/fig411.PNG)
#
# ISO 9000 series certification is for softwares.
#
# ![image.png](figures/fig412.PNG)
#
# ![image.png](figures/fig413.PNG)
#
# First you have to apply then they would give you pre-assessment instructions.Then you send the documentation of product and they send an audit team to check it. nIn compliance audit they give the result of the audit and then they tell you to register. Then they keep a continuous inspection in time interval.
#
# ![image.png](figures/fig414.PNG)
#
# ![image.png](figures/fig415.PNG)

# %% [markdown]
# ![image.png](figures/fig416.PNG)
#
# 68.26% good product lies in -1 to 1 sigma. 99.999998% good product lies in -6 to 6 sigma.
#
# ![image.png](figures/fig417.PNG)
#
# ![image.png](figures/fig418.PNG)
#
# Sigma's value is determined based on these 6 points.
#
# - statistical quality control : Will study market and product quality statistically.
# - methodical approach : creates report on tested approaches and finds the best method.
# - fact and database : creates report on data analysis.
# - project and objective based focus : i.e. developing an OIS system in camera define what threshold is optimal for most of the user
# - customer focus :
# - team work approach to quality management :
#
# ![image.png](figures/fig419.PNG)
#
# ![image.png](figures/fig420.PNG)
#
# sustainable success means long term development.
#
# ![image.png](figures/fig421.PNG)
#
# ![image.png](figures/fig422.PNG)
#
# ![image.png](figures/fig423.PNG)
#
# ![image.png](figures/fig424.PNG)
#
# ![image.png](figures/fig425.PNG)
#
# Product may have some error or may break down thats why we need a maintenance team.
#
# ![image.png](figures/fig426.PNG)
#
# ![image.png](figures/fig427.PNG)
#
# ![image.png](figures/fig428.PNG)

# %% [markdown]
# - Lack of traceability : Its very hard to trace the error or bug.
#
# ![image.png](figures/fig429.PNG)
#
# ![image.png](figures/fig430.PNG)
#
# ![image.png](figures/fig431.PNG)
#
# ![image.png](figures/fig432.PNG)
#
# Total sdlc's 67% cost is spent on maintenance.
#
# ![image.png](figures/fig433.PNG)
#
# ![image.png](figures/fig434.PNG)
#
# ![image.png](figures/fig435.PNG)
#
# Reuse or remake a existing product is called re-engineering.
#
# ![image.png](figures/fig436.PNG)
#
# ![image.png](figures/fig437.PNG)
#
# ![image.png](figures/fig438.PNG)

# %% [markdown]
# ![image.png](figures/fig439.PNG)
#
# ![image.png](figures/fig440.PNG)
#
# ![image.png](figures/fig441.PNG)
#
# ![image.png](figures/fig442.PNG)
#
# ![image.png](figures/fig443.PNG)
#
# ![image.png](figures/fig444.PNG)
#
# ![image.png](figures/fig445.PNG)
#
# ![image.png](figures/fig446.PNG)
#
# ![image.png](figures/fig447.PNG)
#
# ![image.png](figures/fig448.PNG)
#
# ![image.png](figures/fig449.PNG)
#
# ![image.png](figures/fig450.PNG)
#
# ![image.png](figures/fig451.PNG)

# %% [markdown]
# # That's all for this lecture!
