# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>

# %% [markdown]
# # Video Link : https://photos.app.goo.gl/8xoxswnyoDCfwrJY8

# %% [markdown]
# ![image.png](figures/fig13.PNG)

# %% [markdown]
# * Being Responsible : If you have application skills but if you are not responsible than you might harm your company. Like if don't take responsibility of delivering application in time then the company may suffer from losses.
#
# * Honesty : If you are not honest and ethically responsible you'll cause harm to the image of the company and you.
#
# * Ethical behaviour : This includes following protocol that are morally correct.

# %% [markdown]
# ![image.png](figures/fig14.PNG)
#
# * Confidentiality : As an employee one must maintain confidentiality of client, employee, company's trade secret, company's business policy, secret documentation/ code. Like when a new product is launched it creates a hype that boosts sells but if you leak the specification before the correct time then it may harm the company or if you share the code of a new application other might copy and make the same product like you that isn't good for the company. Let's assume you are a DB admin of a bank now if you leak credentials of clients they can suffer from card fraud.
#
# * Competence : Competence is like the bandwidth of your skills. You should only take task that is within your skill level or bandwidth of you skills. You shouldn't take tasks that are beyond your competence. So ethically you should always show what you can do, don't misrepresent your competence level. Like you are a front end developer so you shouldn't apply for machine learning jobs or shouldn't take machine learning tasks cause that is out of you knowledge if you misrepresent yourself that you can do eventually you will not bring benefit to the company rather you might harm it. If you know machine learning only then you should apply for it. Again let's suppose you are a tester of a mobile camera of a company now there's a problem in the camera module you should report to the hardware section but you try to solve it yourself and release it to the market. Then the mobiles shows problem and the company have to take back all the mobiles resulting in loss for the company. Handling the hardware side was out you competence so ethically you shouldn't have deal with it.

# %% [markdown]
# ![image.png](figures/fig15.PNG)
#
# * Intellectual property rights : As a developer we shouldn't work with something that goes against the governing laws. Like we should maintain software laws, ICT law & act. Like we are using crack software like windows this is offense against the company who made the software. But we are considered as we live in a 3rd world country. But in other countries if you use crack software than the company can claim copyright and you'll be punished. We shouldn't use other's properties like code or design without their permission due to copyright issues.
#
# * Misuse : As a developer we shouldn't missuse our skills to harm people by using their devices. Like if we hack into other people computers and steal their data or spy on them or if we inject virus in their computers etc.
#
# ![image.png](figures/fig16.PNG)

# %% [markdown]
# ![image.png](figures/fig17.PNG)<br>
# ![image.png](figures/fig18.PNG)

# %% [markdown]
# * Technical component : This basically includes hardware & software, man power etc basically just the components. The development happens here. Protocols/rules , process aren't a part   of this. Let's assume you do coding/software developing or harware imporvements the developments of these parts happen here but the rules I follow to do these stuff isn't a part of this rather it will fall in socio technical system.
#
# * Socio-technical system : The process, protocols of developing something.
#
# ![image.png](figures/fig19.PNG)
#
# * Emergent properties : Emergent properties are those that arise through interactions among smaller parts that alone do not exhibit such properties. Like in a taem of 10 persons I am a part of it. My contribution to the development alone may not be something meaningfull for the system but as a whole when it comes together it's properties become meaningful. Another example can be like a cell. A cell doesn't show the property like when multiple cell put together to form a multicelular organism i.e. flower. There are two types of emergent properties functional and non-functional.
#     1. Functional emergent properties appear when all the parts of a system work together to achieve some objective. For example, a bicycle has the functional property of being a transportation device once it has been assembled from its     components.
#     2. Non-functional emergent properties relate to the behaviour of the system in its operational environment. Examples of non-functional properties are reliability, performance, safety and security. These are often critical for computer-based systems, as failure to achieve some minimal defined level in these properties may make the system unusable. Some users may not need some system functions so the system may be acceptable without them. However, a system that is unreliable or too slow is likely to be rejected by all its users.
#
# * Non-deterministic : This depends on the productivity rate of machine or OS or person. Like you have a old printer and a new printer. Now you give same input to the printers and they both consume same amount of power but one can print 60pager per hour and another can print 30pages an hour. Another example is let's say we give a problem to senior and junior developer the senior developer will solve it quickly as he as experience but the junior developer will have problems solving it so he will take some time to solve it.
#
# * Complex relationships with organizational objectives : Company's objectives does not just depend on the system itself. It depends on the relationship between persons in the organization. Like relationship between developers or management-developers or client-management.

# %% [markdown]
# ![image.png](figures/fig20.PNG)
#
# * Systems engineering : Basically to manage a socio tachnial system we need to specify some terms, need man power, hardware, software. So the combination of these terms is called system engineering. From the diagram we can see all the part of system engineering in which software engineering is a small part.

# %% [markdown]
# ![image.png](figures/fig21.PNG)
#
# The process of Designing the system is at first we need to define the problem/sytem we want to make. To solve the problem or to make the system we need to divide the requirments that is we need to partition it. After that we need to identify sub systems that is we need to divide the system in sub systems. Then We need to assign requirments to sub systems. Then define the functionality of sub systems. Finaly define sub system interfaces.

# %% [markdown]
# ![image.png](figures/fig22.PNG)
#
# When a new system is based on old data(legacy data) then it's called legacy system.In computing, a legacy system is an old method, technology, computer system, or application program, "of, relating to, or being a previous or outdated computer system," yet still in use. Often referencing a system as "legacy" means that it paved the way for the standards that would follow it. This can also imply that the system is out of date or in need of replacement. Like now we are using 3g network after couple of years we'll be using 4g network so in that time we'll call the 3g network a legacy network and 4g is based on 3g network. The system of today is the legacy system of future.<br>
#
# ![image.png](figures/fig23.PNG)<br>
# These are the basic ocmponents of legacy system. These components can be legeacy individualy like application software can be new but support software, system hardware and application data can be legacy. All the components can be legacy also. Making the whole system a legacy system.

# %% [markdown]
# ![image.png](figures/fig24.PNG)<br>
# In these layers the more we go to the bottom the cost changing that layer increases. Like the cost of changing application software is greater than the cost of changing business process. Example: For an automation system lets say you want to change the thershold of attendance this is a business decision so the cost of changing it is low. Now lets say you want to change the database system this falls is application software and support software so the cost of this is high. Now lets say you want to change it from card punch to facial recognition this falls in hardware and it's cost is very high. To change the hardware you need to change all of the above systems. So when you change a system in this layes you have to change the systems above it.

# %% [markdown]
# ![image.png](figures/fig25.PNG)
#
# When a failure of a system can cause economic losses, physical damage or human life loss then it's called a **critical system.**
#
# * Safety critical systems : Like air traffic control, nuclear power plant, hospital electricity, deep sea oil rig etc. Failure in these systems can cause loss of life or damage to the environment.
#
# * Mission critical systems : is a  electronic or electromechanical system that is fundamentally necessary to the success of a specific operation. Like when astronauts goto space their navigation system is essential for mission success if it fails to mission will be in trouble.
#
# * Business-critical systems : Like in banking sectors if a bank is hacked or it's customers information are leaked or the server is down than the bank will suffer from economic losses.

# %% [markdown]
# ![image.png](figures/fig26.PNG)
#
# The acceptance of a system depends on user’s degree of trust. That is how much a user can depend on the system. If it's dependable then the system is accepted otherwise declined.
#
# ![image.png](figures/fig27.PNG)
# * Availability : The system should be on demand. Like we use bkash for money transfer or flexiload. Cause it's more available to us than bkash outlets. We can use it whenever we want.
# * Reliability : Like when we use bkash we are sure the transaction will be completely reliable. But let's say there's a new app like bkash in which when you do flexiload the transaction is correct 70% of the times. So the new app is less reliable.
# * Safety : When we use a system safety is related to it's hardware part. Like when we use a mobile is it safe to use? Cause samsung note7 had exploded many times. So user safety must be ensured.
# * Security : Lets say for bank system the firewall of the system is weak for that it can be easily hacked. And the money can be stolen or data of users can be stole resulting in card frauds. So high security is a must for a system so that the system can't be compromised.
#
# ![image.png](figures/fig28.PNG)

# %% [markdown]
# ![image.png](figures/fig29.PNG)

# %% [markdown]
# Cost vs. dependability plot.

# %% [markdown]
# # Thats all for this lecture.
