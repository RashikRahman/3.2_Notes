# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>
#
# ## [See Class Lecture](https://photos.app.goo.gl/Kp1ztcRPiJioZZff8)

# %% [markdown]
# ![image.png](figures/fig105.PNG)
#
# **Project plan structure**
#
# - Introduction : As the name suggest, it'll have the intro of the project.
# - Project organization : Organizations involved in a project.
# - Risk analysis : Defining or analysis types of problem we can face in a project.
# - Hardware & software resource requirements : Identifying resource requirements.
# - Work breakdown : Breaking down the whole project in small parts
# - Project schedule : Defining the completion time of each part of the project
# - Monitoring & reporting mechanism : Mainly done by team lead/project manager daily.
#
# ![image.png](figures/fig106.PNG)
#
#
# ![image.png](figures/fig107.PNG)
#
#
# ![image.png](figures/fig108.PNG)
#
#
# ![image.png](figures/fig109.PNG)
#
# `Here milestone placements are not correct they should be placed after the task is finished like M1 should be placed after T3.`
#
#
# ![image.png](figures/fig110.PNG)
#
# Now let's see how to calculate which milestone will be accomplished first. M3 will be achieved before M1 cause it takes 20days to complete T6 and it takes 23days to complete T3. That's why M3 will be achieved first compared to M1.
#
# ![image.png](figures/fig111.PNG)
#
# ![image.png](figures/fig113.PNG)
#
# ![image.png](figures/fig112.PNG)

# %% [markdown]
# **Risk Management**
#
# - Project risk : Risk of delivering the project in time. Can we do it or not?
# - Product risk : Can we develop/deliver the actual product that the customer wants? We think about this risk here.
# - Business risk : Cost risk, technology change, employee leaves or another company develops same product before us. This type of risks are analyzed here.
#
# ![image.png](figures/fig114.PNG)
#
# ![image.png](figures/fig115.PNG)
#
# ![image.png](figures/fig116.PNG)
#
# ![image.png](figures/fig117.PNG)
#
# `important for viva`
#
# when risk is moderate and above we don't do it.
#
# ![image.png](figures/fig118.PNG)
#
# ![image.png](figures/fig119.PNG)
#
# ![image.png](figures/fig120.PNG)

# %% [markdown]
# ![image.png](figures/fig121.PNG)
#
# ![image.png](figures/fig122.PNG)

# %% [markdown]
# ![image.png](figures/fig123.PNG)
#
# System requirements are two types,
# - Function requirements
# - Non-functional requirements
#
# ![image.png](figures/fig124.PNG)
#
# ![image.png](figures/fig125.PNG)
#
# ![image.png](figures/fig126.PNG)
#
# ![image.png](figures/fig127.PNG)
#
# `this block diagram can come in exam`
#
# ![image.png](figures/fig128.PNG)
#
# ![image.png](figures/fig129.PNG)
#
# ![image.png](figures/fig130.PNG)
#
# ![image.png](figures/fig131.PNG)
#
# ![image.png](figures/fig132.PNG)
#
# ![image.png](figures/fig133.PNG)
#
# ![image.png](figures/fig134.PNG)
#
# ![image.png](figures/fig135.PNG)
#
# ![image.png](figures/fig136.PNG)

# %% [markdown]
# # That's all for this lecture!
